# %%
from playground import rag_pipeline_for_thesis_data
from IPython.display import Image
Image(filename="./rag_flow.png")

# %%
import logging
logging.getLogger().setLevel(logging.ERROR)

# %%
response = rag_pipeline_for_thesis_data(query="What is Onur's main topic")
response.content
# Out:
# "Onur Yuksel's main topic is the use of Cellular Automata as a resource for synthetic training data and how properties of CA rules relate to learning."

# %%
response = rag_pipeline_for_thesis_data(query="What technologies did Onur use?")
response.content
# Out:
# 'Onur Yuksel used Cellular Automata and Neural Networks (NN) in his thesis.'

# %%
response = rag_pipeline_for_thesis_data(query="What are Onur's conclusions")
response.content
# Out:
# "Onur Yuksel's conclusions are that there are three behavioral patterns of 1-hidden-layered networks: (I) networks that exhibit convergence to zero uncertainty, (II) networks that struggle at non-zero uncertainty values with low variance throughout the experiment parameter space, and (III) networks that exhibit high uncertainty variance."

# %%
response = rag_pipeline_for_thesis_data(query="")
response.content
# Out:
# 'The thesis does not provide specific information about the parameters of the cellular automaton (CA) used by Onur Yuksel in relation to the uncertainty of the neural network (NN).'
